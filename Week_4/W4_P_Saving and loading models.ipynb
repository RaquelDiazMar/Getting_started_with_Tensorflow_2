# %% [markdown]
# ## Saving and loading models, with application to the EuroSat dataset

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ![EuroSAT overview image](https://github.com/phelber/EuroSAT/blob/master/eurosat_overview_small.jpg?raw=true)
#
# #### The EuroSAT dataset
#
# The [EuroSAT dataset](https://github.com/phelber/EuroSAT) consists of 27000 labelled Sentinel-2 satellite images of different land uses: residential, industrial, highway, river, forest, pasture, herbaceous vegetation, annual crop, permanent crop and sea/lake. For a reference, see the following papers:
# - Eurosat: A novel dataset and deep learning benchmark for land use and land cover classification. Patrick Helber, Benjamin Bischke, Andreas Dengel, Damian Borth. IEEE Journal of Selected Topics in Applied Earth Observations and Remote Sensing, 2019.
# - Introducing EuroSAT: A Novel Dataset and Deep Learning Benchmark for Land Use and Land Cover Classification. Patrick Helber, Benjamin Bischke, Andreas Dengel. 2018 IEEE International Geoscience and Remote Sensing Symposium, 2018.
#
# The goal is to construct a neural network that classifies a satellite image into one of these 10 classes, as well as applying some saving and loading techniques.

# %% [markdown]
# #### Import the data

# %%
def load_eurosat_data():
    data_dir = 'data/'
    x_train = np.load(os.path.join(data_dir, 'x_train.npy'))
    y_train = np.load(os.path.join(data_dir, 'y_train.npy'))
    x_test  = np.load(os.path.join(data_dir, 'x_test.npy'))
    y_test  = np.load(os.path.join(data_dir, 'y_test.npy'))
    return (x_train, y_train), (x_test, y_test)

(x_train, y_train), (x_test, y_test) = load_eurosat_data()
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# #### Build the neural network model

# %% [markdown]
# Construct a model to fit to the data. Using the Sequential API, build a model according to the following specifications:
#
# * The model should use the input_shape in the function argument to set the input size in the first layer.
# * The first layer should be a Conv2D layer with 16 filters, a 3x3 kernel size, a ReLU activation function and 'SAME' padding. Name this layer 'conv_1'.
# * The second layer should also be a Conv2D layer with 8 filters, a 3x3 kernel size, a ReLU activation function and 'SAME' padding. Name this layer 'conv_2'.
# * The third layer should be a MaxPooling2D layer with a pooling window size of 8x8. Name this layer 'pool_1'.
# * The fourth layer should be a Flatten layer, named 'flatten'.
# * The fifth layer should be a Dense layer with 32 units, a ReLU activation. Name this layer 'dense_1'.
# * The sixth and final layer should be a Dense layer with 10 units and softmax activation. Name this layer 'dense_2'.
#
# In total, the network should have 6 layers.

# %%
def get_new_model(input_shape):
    """
    This function should build a Sequential model according to the above specification. Ensure the 
    weights are initialised by providing the input_shape argument in the first layer, given by the
    function argument.
    Your function should also compile the model with the Adam optimiser, sparse categorical cross
    entropy loss function, and a single accuracy metric.
    """
    model = Sequential([
        Conv2D(16, (3,3), activation='relu', padding='SAME', input_shape=input_shape, name='conv_1'),
        Conv2D(8, (3,3), activation='relu', padding='SAME', name='conv_2'),
        MaxPooling2D((8,8), name='pool_1'),
        Flatten(name='flatten'),
        Dense(32, activation='relu', name='dense_1'),
        Dense(10, activation='softmax', name='dense_2')
    ])
    
    model.compile(optimizer='adam', 
                  loss='sparse_categorical_crossentropy', 
                  metrics=['accuracy'])
    
    return model

# %% [markdown]
# #### Compile and evaluate the model

# %%
model = get_new_model(x_train[0].shape)

# %%
def get_test_accuracy(model, x_test, y_test):
    """Test model classification accuracy"""
    test_loss, test_acc = model.evaluate(x=x_test, y=y_test, verbose=0)
    print('accuracy: {acc:0.3f}'.format(acc=test_acc))

# %%
# Print the model summary and calculate its initialised test accuracy

model.summary()
get_test_accuracy(model, x_test, y_test)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 64, 64, 8)         1160
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 8, 8, 8)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                16416
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 18,354
# Trainable params: 18,354
# Non-trainable params: 0
# _________________________________________________________________
# accuracy: 0.077

# %% [markdown]
# #### Create checkpoints to save model during training, with a criterion
#
# - `checkpoint_every_epoch`: checkpoint that saves the model weights every epoch during training
# - `checkpoint_best_only`: checkpoint that saves only the weights with the highest validation accuracy. Use the testing data as the validation data.
# - `early_stopping`: early stopping object that ends training if the validation accuracy has not improved in 3 epochs.

# %%
def get_checkpoint_every_epoch():
    """
    This function should return a ModelCheckpoint object that:
    - saves the weights only at the end of every epoch
    - saves into a directory called 'checkpoints_every_epoch' inside the current working directory
    - generates filenames in that directory like 'checkpoint_XXX' where
      XXX is the epoch number formatted to have three digits, e.g. 001, 002, 003, etc.
    """
    cp_path = 'checkpoints_every_epoch/checkpoint_{epoch:03d}'
    
    return ModelCheckpoint(
        filepath = cp_path,
        frequency='epoch',
        save_weights_only=True, 
        verbose=1)
    


def get_checkpoint_best_only():
    """
    This function should return a ModelCheckpoint object that:
    - saves only the weights that generate the highest validation (testing) accuracy
    - saves into a directory called 'checkpoints_best_only' inside the current working directory
    - generates a file called 'checkpoints_best_only/checkpoint' 
    """
    cp_path = 'checkpoints_best_only/checkpoint'
    
    return ModelCheckpoint(
        filepath = cp_path,
        frequency='epoch',
        save_best_only=True,
        monitor='val_accuracy',
        save_weights_only=True, 
        verbose=1)

# %%
def get_early_stopping():
    """
    This function should return an EarlyStopping callback that stops training when
    the validation (testing) accuracy has not improved in the last 3 epochs.
    HINT: use the EarlyStopping callback with the correct 'monitor' and 'patience'
    """
    
    return EarlyStopping(patience=3, monitor='val_accuracy')

# %%
# create the callbacks

checkpoint_every_epoch = get_checkpoint_every_epoch()
checkpoint_best_only = get_checkpoint_best_only()
early_stopping = get_early_stopping()

# %% [markdown]
# #### Train model using the callbacks
#
# - At the end of every epoch, the model weights are saved into a directory called `checkpoints_every_epoch`
# - At the end of every epoch, the model weights are saved into a directory called `checkpoints_best_only` **only** if those weights lead to the highest test accuracy
# - Training stops when the testing accuracy has not improved in three epochs.
#
#
# - A directory called `checkpoints_every_epoch` containing filenames that include `checkpoint_001`, `checkpoint_002`, etc with the `001`, `002` corresponding to the epoch
# - A directory called `checkpoints_best_only` containing filenames that include `checkpoint`, which contain only the weights leading to the highest testing accuracy

# %%
callbacks = [checkpoint_every_epoch, checkpoint_best_only, early_stopping]
model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test), callbacks=callbacks)
# Out:
# Train on 4000 samples, validate on 1000 samples
# Epoch 1/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 2.1125 - accuracy: 0.1893
# Epoch 00001: saving model to checkpoints_every_epoch/checkpoint_001
#
# Epoch 00001: val_accuracy improved from -inf to 0.29000, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 87s 22ms/sample - loss: 2.1112 - accuracy: 0.1902 - val_loss: 1.8689 - val_accuracy: 0.2900
# Epoch 2/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.5555 - accuracy: 0.4065
# Epoch 00002: saving model to checkpoints_every_epoch/checkpoint_002
#
# Epoch 00002: val_accuracy improved from 0.29000 to 0.45100, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 1.5533 - accuracy: 0.4070 - val_loss: 1.4103 - val_accuracy: 0.4510
# Epoch 3/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.3172 - accuracy: 0.5088
# Epoch 00003: saving model to checkpoints_every_epoch/checkpoint_003
#
# Epoch 00003: val_accuracy improved from 0.45100 to 0.52800, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 1.3163 - accuracy: 0.5088 - val_loss: 1.2888 - val_accuracy: 0.5280
# Epoch 4/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.2096 - accuracy: 0.5552
# Epoch 00004: saving model to checkpoints_every_epoch/checkpoint_004
#
# Epoch 00004: val_accuracy improved from 0.52800 to 0.57500, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 87s 22ms/sample - loss: 1.2094 - accuracy: 0.5555 - val_loss: 1.1967 - val_accuracy: 0.5750
# Epoch 5/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.1152 - accuracy: 0.6026
# Epoch 00005: saving model to checkpoints_every_epoch/checkpoint_005
#
# Epoch 00005: val_accuracy did not improve from 0.57500
# 4000/4000 [==============================] - 87s 22ms/sample - loss: 1.1148 - accuracy: 0.6030 - val_loss: 1.1840 - val_accuracy: 0.5650
# Epoch 6/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 1.0633 - accuracy: 0.6245
# Epoch 00006: saving model to checkpoints_every_epoch/checkpoint_006
#
# Epoch 00006: val_accuracy improved from 0.57500 to 0.59300, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 86s 21ms/sample - loss: 1.0608 - accuracy: 0.6255 - val_loss: 1.1615 - val_accuracy: 0.5930
# Epoch 7/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9940 - accuracy: 0.6379
# Epoch 00007: saving model to checkpoints_every_epoch/checkpoint_007
#
# Epoch 00007: val_accuracy improved from 0.59300 to 0.61500, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 0.9964 - accuracy: 0.6370 - val_loss: 1.0436 - val_accuracy: 0.6150
# Epoch 8/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9646 - accuracy: 0.6550
# Epoch 00008: saving model to checkpoints_every_epoch/checkpoint_008
#
# Epoch 00008: val_accuracy improved from 0.61500 to 0.62300, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 0.9640 - accuracy: 0.6550 - val_loss: 1.0487 - val_accuracy: 0.6230
# Epoch 9/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.9117 - accuracy: 0.6734
# Epoch 00009: saving model to checkpoints_every_epoch/checkpoint_009
#
# Epoch 00009: val_accuracy did not improve from 0.62300
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 0.9105 - accuracy: 0.6743 - val_loss: 1.0577 - val_accuracy: 0.6200
# Epoch 10/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8637 - accuracy: 0.6865
# Epoch 00010: saving model to checkpoints_every_epoch/checkpoint_010
#
# Epoch 00010: val_accuracy improved from 0.62300 to 0.64400, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 85s 21ms/sample - loss: 0.8644 - accuracy: 0.6860 - val_loss: 0.9558 - val_accuracy: 0.6440
# Epoch 11/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.8266 - accuracy: 0.7044
# Epoch 00011: saving model to checkpoints_every_epoch/checkpoint_011
#
# Epoch 00011: val_accuracy improved from 0.64400 to 0.65100, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 84s 21ms/sample - loss: 0.8285 - accuracy: 0.7038 - val_loss: 0.9421 - val_accuracy: 0.6510
# Epoch 12/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7927 - accuracy: 0.7150
# Epoch 00012: saving model to checkpoints_every_epoch/checkpoint_012
#
# Epoch 00012: val_accuracy did not improve from 0.65100
# 4000/4000 [==============================] - 84s 21ms/sample - loss: 0.7916 - accuracy: 0.7150 - val_loss: 0.9328 - val_accuracy: 0.6500
# Epoch 13/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7532 - accuracy: 0.7248
# Epoch 00013: saving model to checkpoints_every_epoch/checkpoint_013
#
# Epoch 00013: val_accuracy improved from 0.65100 to 0.68400, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 84s 21ms/sample - loss: 0.7527 - accuracy: 0.7245 - val_loss: 0.8873 - val_accuracy: 0.6840
# Epoch 14/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7429 - accuracy: 0.7369
# Epoch 00014: saving model to checkpoints_every_epoch/checkpoint_014
#
# Epoch 00014: val_accuracy did not improve from 0.68400
# 4000/4000 [==============================] - 84s 21ms/sample - loss: 0.7467 - accuracy: 0.7358 - val_loss: 0.9794 - val_accuracy: 0.6510
# Epoch 15/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.7254 - accuracy: 0.7359
# Epoch 00015: saving model to checkpoints_every_epoch/checkpoint_015
#
# Epoch 00015: val_accuracy improved from 0.68400 to 0.68500, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 86s 22ms/sample - loss: 0.7244 - accuracy: 0.7362 - val_loss: 0.8590 - val_accuracy: 0.6850
# Epoch 16/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6993 - accuracy: 0.7434
# Epoch 00016: saving model to checkpoints_every_epoch/checkpoint_016
#
# Epoch 00016: val_accuracy improved from 0.68500 to 0.69000, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 89s 22ms/sample - loss: 0.6994 - accuracy: 0.7430 - val_loss: 0.8532 - val_accuracy: 0.6900
# Epoch 17/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6726 - accuracy: 0.7639
# Epoch 00017: saving model to checkpoints_every_epoch/checkpoint_017
#
# Epoch 00017: val_accuracy improved from 0.69000 to 0.69500, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 92s 23ms/sample - loss: 0.6703 - accuracy: 0.7648 - val_loss: 0.8222 - val_accuracy: 0.6950
# Epoch 18/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6499 - accuracy: 0.7664
# Epoch 00018: saving model to checkpoints_every_epoch/checkpoint_018
#
# Epoch 00018: val_accuracy did not improve from 0.69500
# 4000/4000 [==============================] - 89s 22ms/sample - loss: 0.6507 - accuracy: 0.7665 - val_loss: 0.8957 - val_accuracy: 0.6680
# Epoch 19/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6270 - accuracy: 0.7702
# Epoch 00019: saving model to checkpoints_every_epoch/checkpoint_019
#
# Epoch 00019: val_accuracy did not improve from 0.69500
# 4000/4000 [==============================] - 89s 22ms/sample - loss: 0.6266 - accuracy: 0.7700 - val_loss: 0.8578 - val_accuracy: 0.6940
# Epoch 20/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.6171 - accuracy: 0.7782
# Epoch 00020: saving model to checkpoints_every_epoch/checkpoint_020
#
# Epoch 00020: val_accuracy improved from 0.69500 to 0.69800, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 92s 23ms/sample - loss: 0.6157 - accuracy: 0.7788 - val_loss: 0.8214 - val_accuracy: 0.6980
# Epoch 21/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5878 - accuracy: 0.7820
# Epoch 00021: saving model to checkpoints_every_epoch/checkpoint_021
#
# Epoch 00021: val_accuracy improved from 0.69800 to 0.70800, saving model to checkpoints_best_only/checkpoint
# 4000/4000 [==============================] - 90s 23ms/sample - loss: 0.5879 - accuracy: 0.7818 - val_loss: 0.7817 - val_accuracy: 0.7080
# Epoch 22/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5921 - accuracy: 0.7825
# Epoch 00022: saving model to checkpoints_every_epoch/checkpoint_022
#
# Epoch 00022: val_accuracy did not improve from 0.70800
# 4000/4000 [==============================] - 88s 22ms/sample - loss: 0.5931 - accuracy: 0.7818 - val_loss: 0.8502 - val_accuracy: 0.6870
# Epoch 23/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5792 - accuracy: 0.7906
# Epoch 00023: saving model to checkpoints_every_epoch/checkpoint_023
#
# Epoch 00023: val_accuracy did not improve from 0.70800
# 4000/4000 [==============================] - 83s 21ms/sample - loss: 0.5804 - accuracy: 0.7908 - val_loss: 0.8190 - val_accuracy: 0.7050
# Epoch 24/50
# 3968/4000 [============================>.] - ETA: 0s - loss: 0.5452 - accuracy: 0.8054
# Epoch 00024: saving model to checkpoints_every_epoch/checkpoint_024
#
# Epoch 00024: val_accuracy did not improve from 0.70800
# 4000/4000 [==============================] - 82s 21ms/sample - loss: 0.5443 - accuracy: 0.8058 - val_loss: 0.8223 - val_accuracy: 0.7030

# %% [markdown]
# #### Create new instance of model and load on both sets of weights
#
# - `model_last_epoch` should contain the weights from the latest saved epoch
# - `model_best_epoch` should contain the weights from the saved epoch with the highest testing accuracy
#
# `tf.train.latest_checkpoint` _function to get the filename of the latest saved checkpoint file. Check the docs_ [_here_](https://www.tensorflow.org/api_docs/python/tf/train/latest_checkpoint).

# %%
def get_model_last_epoch(model):
    """
    This function should create a new instance of the CNN you created earlier,
    load on the weights from the last training epoch, and return this model.
    """
    model.load_weights(tf.train.latest_checkpoint(checkpoint_dir='checkpoints_every_epoch'))
    
    return model
    
    
    
def get_model_best_epoch(model):
    """
    This function should create a new instance of the CNN you created earlier, load 
    on the weights leading to the highest validation accuracy, and return this model.
    """
    model.load_weights('checkpoints_best_only/checkpoint')
    
    return model

# %%
# create two models: one with the weights from the last training
# epoch, and one with the weights leading to the highest validation (testing) accuracy.
# Verify that the second has a higher validation (testing) accuarcy.

model_last_epoch = get_model_last_epoch(get_new_model(x_train[0].shape))
model_best_epoch = get_model_best_epoch(get_new_model(x_train[0].shape))
print('Model with last epoch weights:')
get_test_accuracy(model_last_epoch, x_test, y_test)
print('')
print('Model with best epoch weights:')
get_test_accuracy(model_best_epoch, x_test, y_test)
# Out:
# Model with last epoch weights:
# accuracy: 0.703
#
# Model with best epoch weights:
# accuracy: 0.708

# %% [markdown]
# #### Load, from scratch, a model trained on the EuroSat dataset.
#
# The path to the model is `models/EuroSatNet.h5`.

# %%
def get_model_eurosatnet():
    """
    This function should return the pretrained EuroSatNet.h5 model.
    """
    model= load_model('models/EuroSatNet.h5')
    
    return model

# %%
# print a summary of the EuroSatNet model, along with its validation accuracy.

model_eurosatnet = get_model_eurosatnet()
model_eurosatnet.summary()
get_test_accuracy(model_eurosatnet, x_test, y_test)
# Out:
# Model: "sequential_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_1 (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# conv_2 (Conv2D)              (None, 64, 64, 16)        6416
# _________________________________________________________________
# pool_1 (MaxPooling2D)        (None, 32, 32, 16)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 32, 32, 16)        2320
# _________________________________________________________________
# conv_4 (Conv2D)              (None, 32, 32, 16)        6416
# _________________________________________________________________
# pool_2 (MaxPooling2D)        (None, 16, 16, 16)        0
# _________________________________________________________________
# conv_5 (Conv2D)              (None, 16, 16, 16)        2320
# _________________________________________________________________
# conv_6 (Conv2D)              (None, 16, 16, 16)        6416
# _________________________________________________________________
# pool_3 (MaxPooling2D)        (None, 8, 8, 16)          0
# _________________________________________________________________
# conv_7 (Conv2D)              (None, 8, 8, 16)          2320
# _________________________________________________________________
# conv_8 (Conv2D)              (None, 8, 8, 16)          6416
# _________________________________________________________________
# pool_4 (MaxPooling2D)        (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                8224
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 41,626
# Trainable params: 41,626
# Non-trainable params: 0
# _________________________________________________________________
# accuracy: 0.810
